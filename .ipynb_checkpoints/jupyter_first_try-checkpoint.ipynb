# %%
print("你好")
#计算简单的数学
result = 5 + 3
print(f"5 + 3 = {result}")
# Out:
# 你好
# 5 + 3 = 8

# %%
a = 10
b = 5
sum = a + b
print(f"a+b={sum}")
# Out:
# a+b=15

# %%
difference a - b
print(f"a-b={difference}")
# Out:
#   Cell In[11], line 1
#     difference a - b
#                ^
# SyntaxError: invalid syntax
